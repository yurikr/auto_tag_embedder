# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from fastai import *
from fastai.vision import *
from fastai.callbacks.hooks import *

# %%
path_meta = Path('/content/drive/My Drive/csvfiles/')
train_data = pd.read_csv(path_meta/'iMaterialist_Train_2000.csv')
val_data = pd.read_csv(path_meta/'valid500.csv')

# %%
train_data.head()
# Out:
#                                            file_path                                             labels
# 0  /content/drive/My Drive/iMaterialist2000/538eb...  Dress Shirts;Green;Pink;Female;Collared;Long S...
# 1  /content/drive/My Drive/iMaterialist2000/55362...                         Shorts;Female;Denim;Ripped
# 2  /content/drive/My Drive/iMaterialist2000/59538...  Skirts;Brown;Blue;Gray;Pink;Black;Yellow;Red;F...
# 3  /content/drive/My Drive/iMaterialist2000/59ab9...  Costumes & Cosplay;Neutral;Round Neck;Short Sl...
# 4  /content/drive/My Drive/iMaterialist2000/55519...  T-Shirts;White;Female;Cotton;Round Neck;Short ...

# %%
train_imgs = Path('/content/drive/My Drive/iMaterialist2000')
val_imgs = Path('/content/drive/My Drive/valid500_images')

# %%
import PIL
import os
import matplotlib.image as mpimg
axs = plt.subplots 
idxs = []
for i in range(0,10):
  n = random.randint(1,500)
  idxs.append(n)

print(idxs)
fig, axs = plt.subplots(5,2, figsize=(15,30))
k=0

for i in range(5):
  for j in range(2):          
    Img = val_data.iloc[idxs[k], 0]
    labels = val_data.iloc[idxs[k],1]
    k=k+1
    axs[i][j].imshow(mpimg.imread(os.path.join(val_imgs, Img)))
    axs[i][j].text(0,0,labels)
# Out:
# [159, 395, 452, 298, 459, 75, 141, 406, 322, 90]
